# %%
from dotenv import load_dotenv
import os
import asyncio
load_dotenv()
# Out:
# True

# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
api_key = os.getenv('OPENAI_API_KEY')

# %%
model_client = OpenAIChatCompletionClient(model='gpt-4', api_key=api_key)

# %%
assistant = AssistantAgent(name="my_assistant", model_client=model_client)

# %%
result = await assistant.run(task="Tell me a joke about AI")

# %%
print(result)
# Out:
# messages=[TextMessage(id='71950531-05fa-4f88-af94-4778fbcd1a17', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2025, 12, 17, 1, 15, 35, 717169, tzinfo=datetime.timezone.utc), content='Tell me a joke about AI', type='TextMessage'), TextMessage(id='6967c047-de4a-406d-8f6e-9d8bede300d7', source='my_assistant', models_usage=RequestUsage(prompt_tokens=79, completion_tokens=32), metadata={}, created_at=datetime.datetime(2025, 12, 17, 1, 15, 37, 449978, tzinfo=datetime.timezone.utc), content="Here's one for you:\n\nWhy don't AI assistants ever play hide and seek with humans?\n\nBecause good luck hiding when your Wi-Fi connection gives you away!", type='TextMessage')] stop_reason=None

# %%
print(result.messages[-1].content)
# Out:
# Here's one for you:
#
# Why don't AI assistants ever play hide and seek with humans?
#
# Because good luck hiding when your Wi-Fi connection gives you away!
