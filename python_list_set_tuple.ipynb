# %% [markdown]
# <a href="https://colab.research.google.com/github/iamhariprasanth/60-steps-to-AI/blob/main/python_list_set_tuple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##LIST
fruits = ['apple','bannana','orange']

# %%
print(fruits)

# %%
fruits.append('grapes')

# %%
fruits[2]

# %%
fruits[2]='papaya'

# %%
fruits.remove('grapes')

# %%
print(fruits)

# %%
print(len(fruits))

# %%
col=('red','green','blue')

# %%
col[1]='yellow'

# %%
set_l = {'a',2,"3",5.6}

# %%
set_l[0]={'4'}

# %%
for i in fruits:
  print (i)

# %%
#While
bus_seat_capacity = 50
seats_filled = 0

while seats_filled < bus_seat_capacity:
    seats_filled += 1
    print(f"1 new Passenger onboarded! Seats filled: {seats_filled}/{bus_seat_capacity}")
print("Bus is Full")
# Out:
# 1 new Passenger onboarded! Seats filled: 1/50
# 1 new Passenger onboarded! Seats filled: 2/50
# 1 new Passenger onboarded! Seats filled: 3/50
# 1 new Passenger onboarded! Seats filled: 4/50
# 1 new Passenger onboarded! Seats filled: 5/50
# 1 new Passenger onboarded! Seats filled: 6/50
# 1 new Passenger onboarded! Seats filled: 7/50
# 1 new Passenger onboarded! Seats filled: 8/50
# 1 new Passenger onboarded! Seats filled: 9/50
# 1 new Passenger onboarded! Seats filled: 10/50
# 1 new Passenger onboarded! Seats filled: 11/50
# 1 new Passenger onboarded! Seats filled: 12/50
# 1 new Passenger onboarded! Seats filled: 13/50
# 1 new Passenger onboarded! Seats filled: 14/50
# 1 new Passenger onboarded! Seats filled: 15/50
# 1 new Passenger onboarded! Seats filled: 16/50
# 1 new Passenger onboarded! Seats filled: 17/50
# 1 new Passenger onboarded! Seats filled: 18/50
# 1 new Passenger onboarded! Seats filled: 19/50
# 1 new Passenger onboarded! Seats filled: 20/50
# ...

# %%
#file operatio
file = open("notes.txt",'r')
content = file.read()
print(content)
# Out:
#  This is my first note
